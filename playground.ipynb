# %%
import torch
from model import Model
from torchsummary import summary
import numpy as np

# %%
model = Model()
mask = []
for parameter in model.named_parameters():
    mask.append(np.zeros(parameter))
# Out:
# ('conv1.weight', Parameter containing:
# tensor([[[[ 0.0712, -0.0804, -0.2074],
#           [-0.0920, -0.0607, -0.1211],
#           [ 0.0670, -0.2028,  0.3067]]],
#
#
#         [[[-0.2358, -0.0876,  0.3230],
#           [ 0.3204, -0.0724,  0.1129],
#           [ 0.1125,  0.2755, -0.0457]]],
#
#
#         [[[-0.3169,  0.0448,  0.1930],
#           [-0.1539, -0.0422,  0.1510],
#           [-0.2390, -0.0607, -0.0518]]],
#
#
#         [[[ 0.2633, -0.1192, -0.1660],
#           [ 0.1198,  0.2398, -0.0179],
#           [-0.3278,  0.1502,  0.0907]]],
#
#
#         [[[-0.2874,  0.0710, -0.0706],
#           [ 0.2933, -0.2246,  0.1744],
#           [-0.0857, -0.1324, -0.1012]]],
#
#
#         [[[ 0.2550, -0.2828,  0.0024],
#           [ 0.0896, -0.0705,  0.1656],
#           [-0.2220, -0.1915,  0.1817]]],
#
#
#         [[[ 0.0667, -0.1697,  0.0848],
#           [ 0.2744,  0.0538, -0.0049],
#           [-0.0993, -0.1603, -0.2834]]],
#
#
#         [[[ 0.1496,  0.2901,  0.1000],
# ...

# %%
type(model.named_parameters())
# Out:
# generator

# %%
for a in mask:
    print(a.shape)
